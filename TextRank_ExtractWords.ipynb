# %% [markdown]
# <h1> 기본 텍스트 랭크 작성- 단어 추출</h1>
# <ul>
# 	<li>unordered</li>
# 	<li>undirected</li>
# 	<li>window=5</li>
# 	<li>co-occurrence based</li>
# </ul>

# %%
import os
import json

# %%
#test code

#path 만들기
dir="./2020-02-019.도서자료요약_Sample"
sample_file=os.listdir("./2020-02-019.도서자료요약_Sample")[0]
path=dir+"/"+sample_file 
#file descriptor 생성하고 내용 읽어내기
fstr=open(path,encoding='utf-8').read()
print(sample_file)
#json decode 하기
sample_json=json.loads(fstr)
print(sample_json)
# Out:
# CNTS-00047965957_40_41-0.json
# {'passage_id': 'CNTS-00047965957_40_41-0', 'metadata': {'doc_id': 'CNTS-00047965957', 'doc_type': '도서', 'doc_name': '후진타오 시대의 중국정치', 'author': '조영남', 'publisher': '나남출판', 'published_year': '2006', 'kdc_label': '정치학', 'kdc_code': '340'}, 'chapter': '1부 중국정치개혁의 성과와 모색 1장 정치개혁의 성과와 과제', 'passage': ' 선거개혁도 유사한 문제가 있다. 유권자들은 1979년 현급 지방인대 직접선거 개혁 –제한적 경쟁선거의 도입, 유권자의 후보추천권 보장 – 이후 좀 더 적극적이고 능동적으로 선거에 참여한다. 그래서 1990년대에 들어 직접선거는 정치교육과 사회화를 통해 국민의 정권에 대한 정통성과 수용성을 높이려는 공산당의 동원수단에서 벗어나 점차로 국민의 의지와 요구를 실현하는 수단으로 발전하였다. 그렇지만 중국의 모든 선거는 공산당 일당지배 체제하에 진행된다는 근본적 한계 외에도, 성급 지방인대 대표와 전국인대 대표선거는 여전히 간접선거로 실시되고 있으며, 중앙정부는 말할 것도 없고 지방정부 수장들도 모두 의회에서 간접선거로 선출된다는 문제점이 있다. 이 때문에 선거를 통한 국민의 정치참여 확대도 전보다 나아지기는 했지만 여전히 많은 한계를 갖는다.', 'summary': ' 1979년 지방인대 직접선거 개혁이후 유권자들은 적극적이고 능동적으로 선거에 참여했다. 1990년대에 직접선거는 공산당의 동원수단에서 벗어나 국민의 의지와 요구를 실현하는 수단으로 발전했지만 여전히 문제점과 한계를 가졌다.'}

# %%
#Set example text


#1) open json file
## get path
## get file descriptor
## get str

dir= "./2020-02-019.도서자료요약_Sample"
jsonfd=[]
jsonstr=[]
for file in os.listdir(dir):
    jsonfd.append(open(dir+"/"+file, encoding="utf-8"))
    jsonstr.append(jsonfd[-1].read())

#2) select passages and summaries
jsonobj=[]
count=0
id={}
passage={}
summary={}
for file in jsonstr:
    obj=json.loads(file)
    jsonobj.append(obj)
    id[count]=obj["passage_id"]
    passage[count]=obj["passage"]
    summary[count]=obj["summary"]

# %%
print("Length check",len(passage)==len(summary),"\nFirst set\n","\t\tPassage",passage[0],"\n\t\tSummary",summary[0])
# Out:
# Length check True
# First set
#  		Passage 유럽연합의 경우 작년 12월 11일 ‘유럽 그린 딜(European Green Deal)’이라는 명칭 하에 ▲친환경, 순환 경제로의 이행을 통한 자원의 효율적 사용, ▲생물다양성의 회복 및 환경오염 감소를 목표로 친환경 기술에 대한 투자, ▲에너지부문에서의 탈탄소화, ▲건축물 에너지 효율 향상 등을 위해 대규모 투자를 통한 지속가능발전 전략을 발표하였다. 또한 올해 4월 17일 유럽의회도 결의 채택을 통해 코로나19 팬데믹 이후 경제회복 프로그램에 ‘유럽그린 딜’을 포함할 것을 촉구한 바 있다. 한편 미국의 경우는 작년 2월 7일 화석연료 사용 제한과 온실가스 배출 저감 및 청정에너지 산업에의 투자를 통한 고소득 일자리 창출 등 경제위기 극복을 위한 방안으로서 ‘그린 뉴딜’ 결의안이 하원에서 제출되기도 하였다. 이처럼 주요 국가들의 관심이 ‘그린 뉴딜’에 집중되고 있으므로, 이의 실행을 위한 국제적 협의 및 전략구상이 하반기부터 본격적으로 이루어질 것으로 전망된다.
# 		Summary EU는 작년 12월 효율적 자원 사용·친환경 기술 투자·에너지부문 탈탄소화·건축물 에너지 효율 향상 위한 '유럽그린 딜'을 발표했다. 의회도 올 4월 이를 촉구했고, 미국도 작년 2월 결의안을 제출했다. 이를 위한 국제 협의는 하반기부터 이뤄진다.

# %%
#Tokenize text
from konlpy.tag import Kkma 
from konlpy.utils import pprint

# %%
#품사 태깅하기
kkma=Kkma()
test=kkma.pos(passage[0])
pprint(test)
# Out:
# [('유럽', 'NNG'),
#  ('연합', 'NNG'),
#  ('의', 'JKG'),
#  ('경우', 'NNG'),
#  ('작년', 'NNG'),
#  ('12', 'NR'),
#  ('월', 'NNM'),
#  ('11', 'NR'),
#  ('일', 'NNM'),
#  ('‘', 'SS'),
#  ('유럽', 'NNG'),
#  ('그린', 'NNG'),
#  ('디', 'VV'),
#  ('ㄹ', 'ETD'),
#  ('(', 'SS'),
#  ('European', 'OL'),
#  ('Green', 'OL'),
#  ('Deal', 'OL'),
#  (')', 'SS'),
#  ('’', 'SS'),
#  ('이', 'VCP'),
#  ('라는', 'ETD'),
#  ('명칭', 'NNG'),
#  ('하', 'NNG'),
#  ('에', 'JKM'),
#  ('▲', 'SW'),
#  ('친', 'NNG'),
#  ('환경', 'NNG'),
#  (',', 'SP'),
#  ('순환', 'NNG'),
#  ('경제', 'NNG'),
#  ('로', 'JKM'),
#  ('의', 'JKG'),
#  ('이행', 'NNG'),
#  ('을', 'JKO'),
#  ('통하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('자원', 'NNG'),
#  ('의', 'JKG'),
#  ('효율적', 'NNG'),
#  ('사용', 'NNG'),
#  (',', 'SP'),
#  ('▲', 'SW'),
#  ('생물', 'NNG'),
#  ('다양성', 'NNG'),
#  ('의', 'JKG'),
#  ('회복', 'NNG'),
#  ('및', 'MAG'),
#  ('환경오염', 'NNG'),
#  ('감소', 'NNG'),
#  ('를', 'JKO'),
#  ('목표', 'NNG'),
#  ('로', 'JKM'),
#  ('치', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('환경', 'NNG'),
#  ('기술', 'NNG'),
#  ('에', 'JKM'),
#  ('대하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('투자', 'NNG'),
#  (',', 'SP'),
#  ('▲', 'SW'),
#  ('에너지', 'NNG'),
#  ('부문', 'NNG'),
#  ('에서', 'JKM'),
#  ('의', 'JKG'),
#  ('탈', 'NNG'),
#  ('탄소', 'NNG'),
#  ('화', 'XSN'),
#  (',', 'SP'),
#  ('▲', 'SW'),
#  ('건축물', 'NNG'),
#  ('에너지', 'NNG'),
#  ('효율', 'NNG'),
#  ('향상', 'NNG'),
#  ('등', 'NNB'),
#  ('을', 'JKO'),
#  ('위하', 'VV'),
#  ('어', 'ECS'),
#  ('대규모', 'NNG'),
#  ('투자', 'NNG'),
#  ('를', 'JKO'),
#  ('통하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('지속', 'NNG'),
#  ('가능', 'NNG'),
#  ('발전', 'NNG'),
#  ('전략', 'NNG'),
#  ('을', 'JKO'),
#  ('발표', 'NNG'),
#  ('하', 'XSV'),
#  ('였', 'EPT'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('또', 'MAG'),
#  ('하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('올해', 'NNG'),
#  ('4', 'NR'),
#  ('월', 'NNM'),
#  ('17', 'NR'),
#  ('일', 'NNM'),
#  ('유럽', 'NNG'),
#  ('의회', 'NNG'),
#  ('도', 'JX'),
#  ('결의', 'NNG'),
#  ('채택', 'NNG'),
#  ('을', 'JKO'),
#  ('통하', 'VV'),
#  ('어', 'ECS'),
#  ('코로나', 'NNG'),
#  ('19', 'NR'),
#  ('패', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('데', 'NNB'),
#  ('믹', 'UN'),
#  ('이후', 'NNG'),
#  ('경제', 'NNG'),
#  ('회복', 'NNG'),
#  ('프로그램', 'NNG'),
#  ('에', 'JKM'),
#  ('‘', 'SS'),
#  ('유럽', 'NNG'),
#  ('그린', 'NNG'),
#  ('디', 'VV'),
#  ('ㄹ', 'ETD'),
#  ('’', 'SS'),
#  ('을', 'NNG'),
#  ('포함', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETD'),
#  ('것', 'NNB'),
#  ('을', 'JKO'),
#  ('촉구', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('바', 'NNB'),
#  ('있', 'VV'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('편', 'NNB'),
#  ('미국', 'NNP'),
#  ('의', 'JKG'),
#  ('경우', 'NNG'),
#  ('는', 'JX'),
#  ('작년', 'NNG'),
#  ('2', 'NR'),
#  ('월', 'NNM'),
#  ('7', 'NR'),
#  ('일', 'NNM'),
#  ('화석', 'NNG'),
#  ('연료', 'NNG'),
#  ('사용', 'NNG'),
#  ('제한', 'NNG'),
#  ('과', 'JKM'),
#  ('온실', 'NNG'),
#  ('가스', 'NNG'),
#  ('배출', 'NNG'),
#  ('저감', 'NNG'),
#  ('및', 'MAG'),
#  ('청정', 'NNG'),
#  ('에너지', 'NNG'),
#  ('산업', 'NNG'),
#  ('에', 'JKM'),
#  ('의', 'JKG'),
#  ('투자', 'NNG'),
#  ('를', 'JKO'),
#  ('통하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('고소득', 'NNG'),
#  ('일자리', 'NNG'),
#  ('창출', 'NNG'),
#  ('등', 'NNB'),
#  ('경제', 'NNG'),
#  ('위기', 'NNG'),
#  ('극복', 'NNG'),
#  ('을', 'JKO'),
#  ('위하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('방안', 'NNG'),
#  ('으로서', 'JKM'),
#  ('‘', 'SS'),
#  ('그리', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('뉴딜', 'NNG'),
#  ('’', 'SS'),
#  ('결의', 'NNG'),
#  ('안이', 'NNG'),
#  ('하원', 'NNG'),
#  ('에서', 'JKM'),
#  ('제출', 'NNG'),
#  ('되', 'XSV'),
#  ('기', 'ETN'),
#  ('도', 'JX'),
#  ('하', 'VX'),
#  ('였', 'EPT'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('이처럼', 'MAG'),
#  ('주요', 'NNG'),
#  ('국가', 'NNG'),
#  ('들', 'XSN'),
#  ('의', 'JKG'),
#  ('관심', 'NNG'),
#  ('이', 'JKS'),
#  ('‘', 'SS'),
#  ('그리', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('뉴딜', 'NNG'),
#  ('’', 'SS'),
#  ('에', 'JKM'),
#  ('집중', 'NNG'),
#  ('되', 'XSV'),
#  ('고', 'ECE'),
#  ('있', 'VXV'),
#  ('으므로', 'ECD'),
#  (',', 'SP'),
#  ('이의', 'NNG'),
#  ('실행', 'NNG'),
#  ('을', 'JKO'),
#  ('위하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('국제적', 'NNG'),
#  ('협의', 'NNG'),
#  ('및', 'MAG'),
#  ('전략', 'NNG'),
#  ('구상', 'NNG'),
#  ('이', 'JKS'),
#  ('하반기', 'NNG'),
#  ('부터', 'JX'),
#  ('본격적', 'NNG'),
#  ('으로', 'JKM'),
#  ('이루어지', 'VV'),
#  ('ㄹ', 'ETD'),
#  ('것', 'NNB'),
#  ('으로', 'JKM'),
#  ('전망', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF')]

# %%
passage
# Out:
# {0: '유럽연합의 경우 작년 12월 11일 ‘유럽 그린 딜(European Green Deal)’이라는 명칭 하에 ▲친환경, 순환 경제로의 이행을 통한 자원의 효율적 사용, ▲생물다양성의 회복 및 환경오염 감소를 목표로 친환경 기술에 대한 투자, ▲에너지부문에서의 탈탄소화, ▲건축물 에너지 효율 향상 등을 위해 대규모 투자를 통한 지속가능발전 전략을 발표하였다. 또한 올해 4월 17일 유럽의회도 결의 채택을 통해 코로나19 팬데믹 이후 경제회복 프로그램에 ‘유럽그린 딜’을 포함할 것을 촉구한 바 있다. 한편 미국의 경우는 작년 2월 7일 화석연료 사용 제한과 온실가스 배출 저감 및 청정에너지 산업에의 투자를 통한 고소득 일자리 창출 등 경제위기 극복을 위한 방안으로서 ‘그린 뉴딜’ 결의안이 하원에서 제출되기도 하였다. 이처럼 주요 국가들의 관심이 ‘그린 뉴딜’에 집중되고 있으므로, 이의 실행을 위한 국제적 협의 및 전략구상이 하반기부터 본격적으로 이루어질 것으로 전망된다.'}

# %% [markdown]
# ### 현 문제점 ###
# kkma의 pos()는 품사를 나눠주기 때문에 한 단어도 여러 개로 쪼개진다.
# 따라서 의미 있는 NNG, NP, VV 튜플을 필터링 할 때 pos()으로 반환되는 리스트 안에서의 인덱스가
# 문장 내에서 위치를 의미하지 않는다.
# 문장 내에서 위치/소속 단어를 분별할 방법이 필요하다.
#
# 일단은 TextRank만 시도해본다는 점에서 굳이 포함하지 않겠다.

# %% [markdown]
# **Konlpy에서 사용자 정의 dictionary 생성하기**
#
# 기본적으로 kkma는 dictionary이다.
# 따라서 포함되지 않는 단어는 품사 태깅을 해줄 수 없다.
# 필연적으로 더 큰 규모의 단어 삽입이 필요하다.

# %%
#Pre-process text : 특정 품사 제거, 불용어 제거

#1) check the positions of each word
#2) only include NNG and VV
#3) filter stopwords

#delete stopwords
f=open("stopwords.txt",encoding="utf-8")
stopwords=kkma.pos(f.read())

#new passage object with words-->words & PoS tuples / only NNG, VV
passage_w_pos={}

for index,content in passage.items():
    content_w_pos=kkma.pos(content)
    
    for i,word in enumerate(content_w_pos):
        if word[1] not in ['NNG','VV']:
            print(word[1],"\t",content_w_pos.pop(i))
        if word in stopwords:
            print(content_w_pos.pop(i))
    passage_w_pos[index]=content_w_pos
# Out:
# JKG 	 ('의', 'JKG')
# ('경우', 'NNG')
# NR 	 ('12', 'NR')
# NR 	 ('11', 'NR')
# SS 	 ('‘', 'SS')
# ETD 	 ('ㄹ', 'ETD')
# ('(', 'SS')
# OL 	 ('Green', 'OL')
# SS 	 (')', 'SS')
# VCP 	 ('이', 'VCP')
# ('라는', 'ETD')
# ('하', 'NNG')
# SW 	 ('▲', 'SW')
# SP 	 (',', 'SP')
# JKM 	 ('로', 'JKM')
# ('의', 'JKG')
# JKO 	 ('을', 'JKO')
# ('통하', 'VV')
# JKG 	 ('의', 'JKG')
# ('효율적', 'NNG')
# SP 	 (',', 'SP')
# JKG 	 ('의', 'JKG')
# ('회복', 'NNG')
# JKO 	 ('를', 'JKO')
# ('목표', 'NNG')
# ETD 	 ('ㄴ', 'ETD')
# ('환경', 'NNG')
# JKM 	 ('에', 'JKM')
# ('대하', 'VV')
# SP 	 (',', 'SP')
# JKM 	 ('에서', 'JKM')
# ('의', 'JKG')
# XSN 	 ('화', 'XSN')
# SW 	 ('▲', 'SW')
# NNB 	 ('등', 'NNB')
# ('위하', 'VV')
# JKO 	 ('를', 'JKO')
# ('통하', 'VV')
# JKO 	 ('을', 'JKO')
# ('발표', 'NNG')
# EPT 	 ('였', 'EPT')
# ('다', 'EFN')
# MAG 	 ('또', 'MAG')
# ('하', 'VV')
# NR 	 ('4', 'NR')
# NR 	 ('17', 'NR')
# JX 	 ('도', 'JX')
# ('결의', 'NNG')
# JKO 	 ('을', 'JKO')
# ('통하', 'VV')
# NR 	 ('19', 'NR')
# ETD 	 ('ㄴ', 'ETD')
# ('데', 'NNB')
# JKM 	 ('에', 'JKM')
# ('‘', 'SS')
# ETD 	 ('ㄹ', 'ETD')
# ('’', 'SS')
# XSV 	 ('하', 'XSV')
# ('ㄹ', 'ETD')
# JKO 	 ('을', 'JKO')
# ('촉구', 'NNG')
# ETD 	 ('ㄴ', 'ETD')
# ('바', 'NNB')
# EFN 	 ('다', 'EFN')
# ('.', 'SF')
# ETD 	 ('ㄴ', 'ETD')
# ('편', 'NNB')
# JKG 	 ('의', 'JKG')
# ('경우', 'NNG')
# NR 	 ('2', 'NR')
# NR 	 ('7', 'NR')
# JKM 	 ('과', 'JKM')
# ('온실', 'NNG')
# MAG 	 ('및', 'MAG')
# ('청정', 'NNG')
# JKM 	 ('에', 'JKM')
# ('의', 'JKG')
# JKO 	 ('를', 'JKO')
# ('통하', 'VV')
# NNB 	 ('등', 'NNB')
# JKO 	 ('을', 'JKO')
# ('위하', 'VV')
# JKM 	 ('으로서', 'JKM')
# ('그리', 'VV')
# SS 	 ('’', 'SS')
# JKM 	 ('에서', 'JKM')
# ('제출', 'NNG')
# ETN 	 ('기', 'ETN')
# ('도', 'JX')
# EPT 	 ('였', 'EPT')
# ('다', 'EFN')
# MAG 	 ('이처럼', 'MAG')
# XSN 	 ('들', 'XSN')
# ('의', 'JKG')
# JKS 	 ('이', 'JKS')
# ('‘', 'SS')
# ETD 	 ('ㄴ', 'ETD')
# ('뉴딜', 'NNG')
# JKM 	 ('에', 'JKM')
# ('집중', 'NNG')
# ECE 	 ('고', 'ECE')
# ('있', 'VXV')
# SP 	 (',', 'SP')
# JKO 	 ('을', 'JKO')
# ('위하', 'VV')
# MAG 	 ('및', 'MAG')
# ('전략', 'NNG')
# JKS 	 ('이', 'JKS')
# ('하반기', 'NNG')
# JKM 	 ('으로', 'JKM')
# ('이루어지', 'VV')
# NNB 	 ('것', 'NNB')
# ('으로', 'JKM')
# XSV 	 ('되', 'XSV')
# ('ㄴ다', 'EFN')

# %%
print(passage_w_pos[0])
# Out:
# [('유럽', 'NNG'), ('연합', 'NNG'), ('작년', 'NNG'), ('월', 'NNM'), ('일', 'NNM'), ('유럽', 'NNG'), ('그린', 'NNG'), ('디', 'VV'), ('European', 'OL'), ('Deal', 'OL'), ('’', 'SS'), ('명칭', 'NNG'), ('에', 'JKM'), ('친', 'NNG'), ('환경', 'NNG'), ('순환', 'NNG'), ('경제', 'NNG'), ('이행', 'NNG'), ('ㄴ', 'ETD'), ('자원', 'NNG'), ('사용', 'NNG'), ('▲', 'SW'), ('생물', 'NNG'), ('다양성', 'NNG'), ('및', 'MAG'), ('환경오염', 'NNG'), ('감소', 'NNG'), ('로', 'JKM'), ('치', 'VV'), ('기술', 'NNG'), ('ㄴ', 'ETD'), ('투자', 'NNG'), ('▲', 'SW'), ('에너지', 'NNG'), ('부문', 'NNG'), ('탈', 'NNG'), ('탄소', 'NNG'), (',', 'SP'), ('건축물', 'NNG'), ('에너지', 'NNG'), ('효율', 'NNG'), ('향상', 'NNG'), ('을', 'JKO'), ('어', 'ECS'), ('대규모', 'NNG'), ('투자', 'NNG'), ('ㄴ', 'ETD'), ('지속', 'NNG'), ('가능', 'NNG'), ('발전', 'NNG'), ('전략', 'NNG'), ('하', 'XSV'), ('.', 'SF'), ('ㄴ', 'ETD'), ('올해', 'NNG'), ('월', 'NNM'), ('일', 'NNM'), ('유럽', 'NNG'), ('의회', 'NNG'), ('채택', 'NNG'), ('어', 'ECS'), ('코로나', 'NNG'), ('패', 'VV'), ('믹', 'UN'), ('이후', 'NNG'), ('경제', 'NNG'), ('회복', 'NNG'), ('프로그램', 'NNG'), ('유럽', 'NNG'), ('그린', 'NNG'), ('디', 'VV'), ('을', 'NNG'), ('포함', 'NNG'), ('것', 'NNB'), ('하', 'XSV'), ('있', 'VV'), ('하', 'VV'), ('미국', 'NNP'), ('는', 'JX'), ('작년', 'NNG'), ('월', 'NNM'), ('일', 'NNM'), ('화석', 'NNG'), ('연료', 'NNG'), ('사용', 'NNG'), ('제한', 'NNG'), ('가스', 'NNG'), ('배출', 'NNG'), ('저감', 'NNG'), ('에너지', 'NNG'), ('산업', 'NNG'), ('투자', 'NNG'), ('ㄴ', 'ETD'), ('고소득', 'NNG'), ('일자리', 'NNG'), ('창출', 'NNG'), ('경제', 'NNG'), ('위기', 'NNG'), ('극복', 'NNG'), ('ㄴ', 'ETD'), ('방안', 'NNG'), ('‘', 'SS'), ('ㄴ', 'ETD'), ('뉴딜', 'NNG'), ('결의', 'NNG'), ('안이', 'NNG'), ('하원', 'NNG'), ('되', 'XSV'), ('하', 'VX'), ('.', 'SF'), ('주요', 'NNG'), ('국가', 'NNG'), ('관심', 'NNG'), ('그리', 'VV'), ('’', 'SS'), ('되', 'XSV'), ('으므로', 'ECD'), ('이의', 'NNG'), ('실행', 'NNG'), ('ㄴ', 'ETD'), ('국제적', 'NNG'), ('협의', 'NNG'), ('구상', 'NNG'), ('부터', 'JX'), ('본격적', 'NNG'), ('ㄹ', 'ETD'), ('전망', 'NNG'), ('.', 'SF')]

# %%
#Edge generation: window=5

# %%
#Calculate Importance Score

#1) set S_i=k 

#2) get k

# %%
#Get result

# %% [markdown]
# <h3>결과 평가</h3>
#
# 데이터셋은 passage인자와 summary인자가 있다.
#
# <h4> 답안지 만들기 </h4>
# <ol>
# 	<li>각자를 토큰화한 것을 비교해 summary 속의 단어 토큰 중 passage의 것과 같았던 것을 간추린다. </li>
# 	<li>passage의 인자 중 일반명사는 중요도를 절반으로 선정한다. </li>
# </ol>
#
# <h4> F-feature 계산하기</h4>
# <ol>
# 	<li>Precision을 구한다 : |교집합|/|TR 결과|</ol>
# 	<li>Recall을 구한다: |교집합|/|답안지|</ol>
# 	<li>F-feature을 구한다: 2*P*R/(P+R)</ol>
# </ol>

# %%
#Compare results
